# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from tensorflow.keras.layers import Dense
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
import io
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Flatten
from keras.optimizers import Adam
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import load_model

# %%
#!gdown --id 1iflIk1AxLMjOL_VW19rr2VHcmmMc7D9Q

# %%
from numpy.random import seed
seed(100)

# %% [markdown]
# # Loading the data

# %%
main_df = pd.read_csv("Features_and_Target.csv")

# %%
main_df
# Out:
#        permno  yyyymm ticker        r1m  close_price  AnnouncementReturn  \
# 0       24643  199208     AA -11.830509       64.625           -0.034219
# 1       24643  199209     AA   2.514507       66.250           -0.034219
# 2       24643  199210     AA   5.283019       69.750            0.002048
# 3       24643  199211     AA   1.111111       70.125            0.002048
# 4       24643  199212     AA   2.139037       71.625            0.002048
# ...       ...     ...    ...        ...          ...                 ...
# 28594   89070  201412    ZMH   1.202242      113.420            0.030118
# 28595   89070  201501    ZMH  -1.163816      112.100           -0.013885
# 28596   89070  201502    ZMH   7.395184      120.390           -0.013885
# 28597   89070  201503    ZMH  -2.201182      117.520           -0.013885
# 28598   89070  201504    ZMH  -6.535058      109.840           -0.051092
#
#         betaVIX  BookLeverage  ConvDebt    DolVol  ...  Consumer_sentiment  \
# 0     -0.002155     -1.991768      -1.0 -6.319875  ...              0.3805
# 1     -0.001269     -1.991768      -1.0 -6.289308  ...              0.3780
# 2     -0.001911     -1.991768      -1.0 -6.103797  ...              0.3665
# 3      0.000085     -1.991768      -1.0 -5.755551  ...              0.4265
# 4     -0.006525     -1.991768      -1.0 -6.073234  ...              0.4550
# ...         ...           ...       ...       ...  ...                 ...
# 28594  0.000256     -1.521382       0.0 -8.063711  ...              0.4680
# 28595  0.005394     -1.521382       0.0 -7.463536  ...              0.4905
# 28596 -0.002619     -1.521382       0.0 -7.653775  ...              0.4770
# 28597  0.004160     -1.521382       0.0 -8.047728  ...              0.4650
# 28598 -0.002203     -1.521382       0.0 -7.758223  ...              0.4795
#
#        Date_encode  Investor_sentiment_3MA  Investor_sentiment_6MA  \
# 0                1                     NaN                     NaN
# 1                2                     NaN                     NaN
# 2                3                0.422500                     NaN
# 3                4                0.481250                     NaN
# 4                5                0.569167                     NaN
# ...            ...                     ...                     ...
# 28594          269                0.616750                0.590042
# 28595          270                0.622750                0.601208
# 28596          271                0.598583                0.604125
# 28597          272                0.576917                0.596833
# 28598          273                0.555583                0.589167
#
#        News_sentiment_3MA  News_sentiment_6MA  Consumer_sentiment_3MA  \
# 0                     NaN                 NaN                     NaN
# 1                     NaN                 NaN                     NaN
# 2                0.487161                 NaN                0.375000
# 3                0.488176                 NaN                0.390333
# 4                0.530369                 NaN                0.416000
# ...                   ...                 ...                     ...
# 28594            0.566568            0.545846                0.448833
# 28595            0.590869            0.561545                0.467500
# 28596            0.594520            0.571278                0.478500
# 28597            0.581778            0.574173                0.477500
# 28598            0.570497            0.580683                0.473833
#
#        Consumer_sentiment_6MA  forward_return  target
# 0                         NaN        2.514507       1
# 1                         NaN        5.283019       1
# 2                         NaN        1.111111       1
# 3                         NaN        2.139037       1
# 4                         NaN        3.839441       1
# ...                       ...             ...     ...
# 28594                0.431833       -1.163816       0
# 28595                0.445417        7.395184       1
# 28596                0.456167       -2.201182       0
# 28597                0.463167       -6.535058       0
# 28598                0.470667        4.069556       1
#
# [28599 rows x 36 columns]

# %%
len(main_df["ticker"].unique())
# Out:
# 137

# %% [markdown]
# # Preprocessing the data

# %%
##Eliminating the missing data
main_df.dropna(subset=['News_sentiment_3MA', 'Consumer_sentiment_3MA', 'Investor_sentiment_3MA','betaVIX', 
           'BookLeverage', 'ConvDebt', 'DolVol', 'hire', 'IdioVol3F', 'IndMom', 'MaxRet',
           'OPLeverage', 'PctAcc', 'RDIPO', 'ReturnSkew', 'Size', 'STreversal','zerotradeAlt1'], inplace=True)

# %%
main_df
# Out:
#        permno  yyyymm ticker       r1m  close_price  AnnouncementReturn  \
# 2       24643  199210     AA  5.283019       69.750            0.002048
# 3       24643  199211     AA  1.111111       70.125            0.002048
# 4       24643  199212     AA  2.139037       71.625            0.002048
# 5       24643  199301     AA  3.839441       74.375           -0.034033
# 6       24643  199302     AA -5.176470       70.125           -0.034033
# ...       ...     ...    ...       ...          ...                 ...
# 28594   89070  201412    ZMH  1.202242      113.420            0.030118
# 28595   89070  201501    ZMH -1.163816      112.100           -0.013885
# 28596   89070  201502    ZMH  7.395184      120.390           -0.013885
# 28597   89070  201503    ZMH -2.201182      117.520           -0.013885
# 28598   89070  201504    ZMH -6.535058      109.840           -0.051092
#
#         betaVIX  BookLeverage  ConvDebt    DolVol  ...  Consumer_sentiment  \
# 2     -0.001911     -1.991768      -1.0 -6.103797  ...              0.3665
# 3      0.000085     -1.991768      -1.0 -5.755551  ...              0.4265
# 4     -0.006525     -1.991768      -1.0 -6.073234  ...              0.4550
# 5      0.003535     -1.991768      -1.0 -6.045333  ...              0.4465
# 6     -0.006632     -1.991768      -1.0 -6.001115  ...              0.4330
# ...         ...           ...       ...       ...  ...                 ...
# 28594  0.000256     -1.521382       0.0 -8.063711  ...              0.4680
# 28595  0.005394     -1.521382       0.0 -7.463536  ...              0.4905
# 28596 -0.002619     -1.521382       0.0 -7.653775  ...              0.4770
# 28597  0.004160     -1.521382       0.0 -8.047728  ...              0.4650
# 28598 -0.002203     -1.521382       0.0 -7.758223  ...              0.4795
#
#        Date_encode  Investor_sentiment_3MA  Investor_sentiment_6MA  \
# 2                3                0.422500                     NaN
# 3                4                0.481250                     NaN
# 4                5                0.569167                     NaN
# 5                6                0.635167                0.528833
# 6                7                0.621000                0.551125
# ...            ...                     ...                     ...
# 28594          269                0.616750                0.590042
# 28595          270                0.622750                0.601208
# 28596          271                0.598583                0.604125
# 28597          272                0.576917                0.596833
# 28598          273                0.555583                0.589167
#
#        News_sentiment_3MA  News_sentiment_6MA  Consumer_sentiment_3MA  \
# 2                0.487161                 NaN                0.375000
# 3                0.488176                 NaN                0.390333
# 4                0.530369                 NaN                0.416000
# 5                0.577251            0.532206                0.442667
# 6                0.606878            0.547527                0.444833
# ...                   ...                 ...                     ...
# 28594            0.566568            0.545846                0.448833
# 28595            0.590869            0.561545                0.467500
# 28596            0.594520            0.571278                0.478500
# 28597            0.581778            0.574173                0.477500
# 28598            0.570497            0.580683                0.473833
#
#        Consumer_sentiment_6MA  forward_return  target
# 2                         NaN        1.111111       1
# 3                         NaN        2.139037       1
# 4                         NaN        3.839441       1
# 5                    0.408833       -5.176470       0
# 6                    0.417583       -8.021390       0
# ...                       ...             ...     ...
# 28594                0.431833       -1.163816       0
# 28595                0.445417        7.395184       1
# 28596                0.456167       -2.201182       0
# 28597                0.463167       -6.535058       0
# 28598                0.470667        4.069556       1
#
# [26890 rows x 36 columns]

# %%
#Transform the data, dividing it by 100
main_df['forward_return_div100'] = main_df['forward_return']/100

# %%
#Rolling data set preset
start_year = 1992  # Start year of your dataset
training_years = 8
validation_years = 2
testing_years = 5

train_end_year = start_year + training_years - 1
valid_end_year = train_end_year + validation_years
test_end_year = valid_end_year + testing_years

# Initialize lists to store the splits
training_splits = []
validation_splits = []
testing_splits = []

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit

# %%
#Extract year from yyyymm so that it can work well!
main_df['year'] = main_df['yyyymm'].astype(str).str[:4]

# %%
main_df['year']
# Out:
# 2        1992
# 3        1992
# 4        1992
# 5        1993
# 6        1993
#          ...
# 28594    2014
# 28595    2015
# 28596    2015
# 28597    2015
# 28598    2015
# Name: year, Length: 26890, dtype: object

# %%
main_df['year'] = main_df['year'].astype(int)

# %%
main_df['Date'] = pd.to_datetime(main_df['yyyymm'], format='%Y%m', errors='coerce').dropna()

# %%
main_df['yyyymm'] = main_df['yyyymm'].astype('int')

# %%
# Split the data into features and target
data_use = main_df[['year', "yyyymm", 'Investor_sentiment_3MA', 'News_sentiment_3MA',
          "Consumer_sentiment_3MA", "betaVIX", "BookLeverage", "ConvDebt", "DolVol", "hire",
          "IdioVol3F", "IndMom", "MaxRet", "OPLeverage", "PctAcc", "PctTotAcc", "Price", "RDIPO", "ReturnSkew", "Size",
          "STreversal", "zerotradeAlt1", 'forward_return_div100']]

# Scale the data
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# data_use_scaled = scaler.fit_transform(data_use)

# Convert the data into 3D tensors for the CNN model
# X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

# %%
##Rolling forward!
while test_end_year <= 2022:  # Assuming your dataset goes up to 2020
    # Select the data for the current split
    train_data = data_use[(main_df['year'] >= start_year) & (data_use['year'] <= train_end_year)]
    valid_data = data_use[(main_df['year'] > train_end_year) & (data_use['year'] <= valid_end_year)]
    test_data = data_use[(main_df['year'] > valid_end_year) & (data_use['year'] <= test_end_year)]


    # Append the data to the respective lists
    training_splits.append(train_data)
    validation_splits.append(valid_data)
    testing_splits.append(test_data)

    # Update the start and end years for the next split
    start_year += 5
    train_end_year += 5
    valid_end_year += 5
    test_end_year += 5

# %%
# Define a function for creating and training a neural network model
def create_and_train_nn(X_train, y_train, X_valid, y_valid, X_test, y_test):
    # Standardize the features using StandardScaler
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_valid = scaler.transform(X_valid)
    X_test = scaler.transform(X_test)

    # Create a simple feedforward neural network model
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(1)  # Output layer
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model
    history = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=40, batch_size=64)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)

    # Evaluate the model on the test data
    # y_pred = model.predict(X_test)
    # mse = mean_squared_error(y_test, y_pred)
    return model, history, mse

# %%
##Train the model 

trained_models = []
trained_history = []
mses = []
for train_data, valid_data, test_data in zip(training_splits, validation_splits, testing_splits):
    X_train = train_data[['News_sentiment_3MA', 'Consumer_sentiment_3MA', 'Investor_sentiment_3MA','betaVIX', 
           'BookLeverage', 'ConvDebt', 'DolVol', 'hire', 'IdioVol3F', 'IndMom', 'MaxRet',
           'OPLeverage', 'PctAcc', 'RDIPO', 'ReturnSkew', 'Size', 'STreversal','zerotradeAlt1']]##Extract Training set
    y_train = train_data[["forward_return_div100"]]##Extract training set
    X_valid = valid_data[['News_sentiment_3MA', 'Consumer_sentiment_3MA', 'Investor_sentiment_3MA','betaVIX', 
           'BookLeverage', 'ConvDebt', 'DolVol', 'hire', 'IdioVol3F', 'IndMom', 'MaxRet',
           'OPLeverage', 'PctAcc', 'RDIPO', 'ReturnSkew', 'Size', 'STreversal','zerotradeAlt1']]##Extract validation set
    y_valid = valid_data[["forward_return_div100"]]##Extract validation set
    X_test = test_data[['News_sentiment_3MA', 'Consumer_sentiment_3MA', 'Investor_sentiment_3MA','betaVIX', 
           'BookLeverage', 'ConvDebt', 'DolVol', 'hire', 'IdioVol3F', 'IndMom', 'MaxRet',
           'OPLeverage', 'PctAcc', 'RDIPO', 'ReturnSkew', 'Size', 'STreversal','zerotradeAlt1']]##Extract testing test
    y_test = test_data[["forward_return_div100"]]##Extract testing set

    model, history, mse = create_and_train_nn(X_train, y_train, X_valid, y_valid, X_test, y_test)

    trained_models.append(model)#Obtain the trained model

    trained_history.append(history)#Obtain model history

    mses.append(mse)
    # print(f"Mean Squared Error for this split: {mse}")
# Out:
# Epoch 1/40
# 102/102 [==============================] - 1s 9ms/step - loss: 0.1322 - val_loss: 0.0214
# Epoch 2/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0098 - val_loss: 0.0220
# Epoch 3/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0099 - val_loss: 0.0212
# Epoch 4/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0099 - val_loss: 0.0219
# Epoch 5/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0100 - val_loss: 0.0219
# Epoch 6/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0111 - val_loss: 0.0241
# Epoch 7/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0118 - val_loss: 0.0222
# Epoch 8/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0101 - val_loss: 0.0228
# Epoch 9/40
# 102/102 [==============================] - 1s 8ms/step - loss: 0.0103 - val_loss: 0.0226
# Epoch 10/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0103 - val_loss: 0.0222
# Epoch 11/40
# 102/102 [==============================] - 1s 8ms/step - loss: 0.0105 - val_loss: 0.0220
# Epoch 12/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0107 - val_loss: 0.0236
# Epoch 13/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0108 - val_loss: 0.0241
# Epoch 14/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0120 - val_loss: 0.0288
# Epoch 15/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0133 - val_loss: 0.0254
# Epoch 16/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0114 - val_loss: 0.0226
# Epoch 17/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0114 - val_loss: 0.0239
# Epoch 18/40
# 102/102 [==============================] - 1s 8ms/step - loss: 0.0114 - val_loss: 0.0239
# Epoch 19/40
# 102/102 [==============================] - 1s 8ms/step - loss: 0.0115 - val_loss: 0.0213
# Epoch 20/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0120 - val_loss: 0.0540
# Epoch 21/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0134 - val_loss: 0.0231
# Epoch 22/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0125 - val_loss: 0.0276
# Epoch 23/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0126 - val_loss: 0.0364
# Epoch 24/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0154 - val_loss: 0.0244
# Epoch 25/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0139 - val_loss: 0.0239
# Epoch 26/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0174 - val_loss: 0.0275
# Epoch 27/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0138 - val_loss: 0.0246
# Epoch 28/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0136 - val_loss: 0.0239
# Epoch 29/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0140 - val_loss: 0.0263
# Epoch 30/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0177 - val_loss: 0.0312
# Epoch 31/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0135 - val_loss: 0.0237
# Epoch 32/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0178 - val_loss: 0.0232
# Epoch 33/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0140 - val_loss: 0.0401
# Epoch 34/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0135 - val_loss: 0.0294
# Epoch 35/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0156 - val_loss: 0.0425
# Epoch 36/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0226 - val_loss: 0.0453
# Epoch 37/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0146 - val_loss: 0.0246
# Epoch 38/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0123 - val_loss: 0.0239
# Epoch 39/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0159 - val_loss: 0.0331
# Epoch 40/40
# 102/102 [==============================] - 1s 7ms/step - loss: 0.0149 - val_loss: 0.0325
# 164/164 [==============================] - 0s 2ms/step
# Epoch 1/40
# 126/126 [==============================] - 2s 11ms/step - loss: 0.1759 - val_loss: 0.0060
# Epoch 2/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0148 - val_loss: 0.0048
# Epoch 3/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0149 - val_loss: 0.0051
# Epoch 4/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0149 - val_loss: 0.0050
# Epoch 5/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0155 - val_loss: 0.0058
# Epoch 6/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0203 - val_loss: 0.0065
# Epoch 7/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.1207 - val_loss: 0.0133
# Epoch 8/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0211 - val_loss: 0.0053
# Epoch 9/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0154 - val_loss: 0.0058
# Epoch 10/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0152 - val_loss: 0.0052
# Epoch 11/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0150 - val_loss: 0.0050
# Epoch 12/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0154 - val_loss: 0.0065
# Epoch 13/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0154 - val_loss: 0.0053
# Epoch 14/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0167 - val_loss: 0.0070
# Epoch 15/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0281 - val_loss: 0.0061
# Epoch 16/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0805 - val_loss: 0.0069
# Epoch 17/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0194 - val_loss: 0.0059
# Epoch 18/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0274 - val_loss: 0.0076
# Epoch 19/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0284 - val_loss: 0.0071
# Epoch 20/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0223 - val_loss: 0.0099
# Epoch 21/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0919 - val_loss: 0.0329
# Epoch 22/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0661 - val_loss: 0.0139
# Epoch 23/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0196 - val_loss: 0.0060
# Epoch 24/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0172 - val_loss: 0.0073
# Epoch 25/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0176 - val_loss: 0.0060
# Epoch 26/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0191 - val_loss: 0.0063
# Epoch 27/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0262 - val_loss: 0.0063
# Epoch 28/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0602 - val_loss: 0.0137
# Epoch 29/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0836 - val_loss: 0.0076
# Epoch 30/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0352 - val_loss: 0.0073
# Epoch 31/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0186 - val_loss: 0.0057
# Epoch 32/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0195 - val_loss: 0.0067
# Epoch 33/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0171 - val_loss: 0.0072
# Epoch 34/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0181 - val_loss: 0.0055
# Epoch 35/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.1296 - val_loss: 0.0297
# Epoch 36/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.1173 - val_loss: 0.0054
# Epoch 37/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0187 - val_loss: 0.0063
# Epoch 38/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0164 - val_loss: 0.0058
# Epoch 39/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0183 - val_loss: 0.0081
# Epoch 40/40
# 126/126 [==============================] - 1s 7ms/step - loss: 0.0181 - val_loss: 0.0057
# 153/153 [==============================] - 0s 2ms/step
# Epoch 1/40
# 129/129 [==============================] - 1s 8ms/step - loss: 0.0990 - val_loss: 0.0209
# Epoch 2/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0112 - val_loss: 0.0086
# Epoch 3/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0109 - val_loss: 0.0092
# Epoch 4/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0109 - val_loss: 0.0134
# Epoch 5/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0111 - val_loss: 0.0230
# Epoch 6/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0116 - val_loss: 0.0431
# Epoch 7/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0115 - val_loss: 0.0125
# Epoch 8/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0116 - val_loss: 0.0104
# Epoch 9/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0125 - val_loss: 0.0094
# Epoch 10/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0122 - val_loss: 0.0104
# Epoch 11/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0128 - val_loss: 0.0509
# Epoch 12/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0118 - val_loss: 0.0599
# Epoch 13/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0141 - val_loss: 0.0161
# Epoch 14/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0122 - val_loss: 0.0140
# Epoch 15/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0136 - val_loss: 0.0410
# Epoch 16/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0145 - val_loss: 0.0528
# Epoch 17/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0158 - val_loss: 0.0110
# Epoch 18/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0159 - val_loss: 0.0143
# Epoch 19/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0150 - val_loss: 0.0224
# Epoch 20/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0138 - val_loss: 0.0096
# Epoch 21/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0139 - val_loss: 0.0206
# Epoch 22/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0150 - val_loss: 0.0151
# Epoch 23/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0148 - val_loss: 0.0628
# Epoch 24/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0153 - val_loss: 0.0175
# Epoch 25/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0178 - val_loss: 0.0120
# Epoch 26/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0169 - val_loss: 0.0082
# Epoch 27/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0188 - val_loss: 0.0105
# Epoch 28/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0285 - val_loss: 0.0324
# Epoch 29/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0159 - val_loss: 0.0197
# Epoch 30/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0304 - val_loss: 0.0177
# Epoch 31/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0144 - val_loss: 0.0160
# Epoch 32/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0175 - val_loss: 0.0113
# Epoch 33/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0149 - val_loss: 0.0292
# Epoch 34/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0211 - val_loss: 0.0176
# Epoch 35/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0201 - val_loss: 0.0159
# Epoch 36/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0154 - val_loss: 0.0279
# Epoch 37/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0257 - val_loss: 0.0118
# Epoch 38/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0304 - val_loss: 0.0152
# Epoch 39/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0153 - val_loss: 0.0301
# Epoch 40/40
# 129/129 [==============================] - 1s 7ms/step - loss: 0.0240 - val_loss: 0.0248
# 137/137 [==============================] - 0s 2ms/step
# Epoch 1/40
# 119/119 [==============================] - 2s 14ms/step - loss: 0.0544 - val_loss: 0.0074
# Epoch 2/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0105 - val_loss: 0.0087
# Epoch 3/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0104 - val_loss: 0.0113
# Epoch 4/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0113 - val_loss: 0.0070
# Epoch 5/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0105 - val_loss: 0.0727
# Epoch 6/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0111 - val_loss: 0.0082
# Epoch 7/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0124 - val_loss: 0.0209
# Epoch 8/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0118 - val_loss: 0.0599
# Epoch 9/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0123 - val_loss: 0.1605
# Epoch 10/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0246 - val_loss: 0.0489
# Epoch 11/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0109 - val_loss: 0.0213
# Epoch 12/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0153 - val_loss: 0.0348
# Epoch 13/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0104 - val_loss: 0.0074
# Epoch 14/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0111 - val_loss: 0.0096
# Epoch 15/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0123 - val_loss: 0.0325
# Epoch 16/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0120 - val_loss: 0.0328
# Epoch 17/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0140 - val_loss: 0.0378
# Epoch 18/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0114 - val_loss: 0.0397
# Epoch 19/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0123 - val_loss: 0.0258
# Epoch 20/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0149 - val_loss: 0.1813
# Epoch 21/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0140 - val_loss: 0.0152
# Epoch 22/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0136 - val_loss: 0.0465
# Epoch 23/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0132 - val_loss: 0.1037
# Epoch 24/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0159 - val_loss: 0.0120
# Epoch 25/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0136 - val_loss: 0.0091
# Epoch 26/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0140 - val_loss: 0.0073
# Epoch 27/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0151 - val_loss: 0.1150
# Epoch 28/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0179 - val_loss: 0.0131
# Epoch 29/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0146 - val_loss: 0.1457
# Epoch 30/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0146 - val_loss: 0.0140
# Epoch 31/40
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0134 - val_loss: 0.0070
# Epoch 32/40
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0141 - val_loss: 0.0241
# Epoch 33/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0168 - val_loss: 0.1227
# Epoch 34/40
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0354 - val_loss: 0.0281
# Epoch 35/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0142 - val_loss: 0.0102
# Epoch 36/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0138 - val_loss: 0.0078
# Epoch 37/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0161 - val_loss: 0.0628
# Epoch 38/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0149 - val_loss: 0.0364
# Epoch 39/40
# 119/119 [==============================] - 1s 7ms/step - loss: 0.0217 - val_loss: 0.0099
# Epoch 40/40
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0116 - val_loss: 0.1608
# 120/120 [==============================] - 0s 2ms/step

# %%
mses
# Out:
# [0.018183190664660846,
#  0.01828451866545514,
#  0.01934762925025002,
#  0.1828708893936353]

# %%
trained_models[1].summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                1216
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 3,329
# Trainable params: 3,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(trained_models[0], to_file='model.png', show_shapes=True)

# %%
trained_history[1].history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
losses_data = pd.DataFrame(trained_history[1].history)
plt.grid(True)
plt.plot(losses_data.index, losses_data["loss"], "-b", label="loss")
plt.plot(losses_data.index, losses_data["val_loss"], "-r", label="value loss")
plt.legend()
plt.show()

# %%
losses_data
# Out:
#         loss  val_loss
# 0   0.038915  0.017043
# 1   0.021195  0.010454
# 2   0.016984  0.010030
# 3   0.015695  0.012190
# 4   0.015218  0.010620
# 5   0.014382  0.008585
# 6   0.013883  0.007485
# 7   0.013584  0.007608
# 8   0.013202  0.007209
# 9   0.013047  0.007326
# 10  0.013108  0.007484
# 11  0.012608  0.007223
# 12  0.012409  0.008060
# 13  0.012520  0.007355
# 14  0.012177  0.007588
# 15  0.012135  0.007242
# 16  0.013008  0.007516
# 17  0.012104  0.007538
# 18  0.011879  0.006656
# 19  0.011717  0.006884
# 20  0.011649  0.007028
# 21  0.011756  0.007384
# 22  0.011413  0.007290
# 23  0.011365  0.006993
# 24  0.011381  0.007100
# 25  0.011478  0.007823
# 26  0.011245  0.007888
# 27  0.011258  0.007576
# 28  0.011033  0.009031
# 29  0.011464  0.007838
# 30  0.011051  0.007397
# 31  0.011009  0.007441
# 32  0.010945  0.007183
# 33  0.010869  0.007548
# 34  0.010784  0.007299
# 35  0.010599  0.008146
# 36  0.010597  0.008006
# 37  0.010569  0.008406
# 38  0.010572  0.008770
# 39  0.010562  0.008724

# %% [markdown]
# # Testing the data

# %%
#Obtain the data testing sample, date range from 2007-2012
Date_holder = testing_splits[1]["yyyymm"].unique()

# %%
# type(testing_splits[1])

# %%
# Test_df = testing_splits[1]

# %%
# Test_df.reset_index(inplace = True, drop = True)

# %%
# Test_df

# %%
# Test_data = Test_df[Test_df['yyyymm'] == 201108]
# Test_data.reset_index(inplace = True, drop = True)
# Test_data

# %%
# X_test = Test_data[['Investor_sentiment_3MA', 'News_sentiment_3MA',
#       "Consumer_sentiment_3MA", "betaVIX", "BookLeverage", "ConvDebt", "DolVol", "hire",
#       "IdioVol3F", "IndMom", "MaxRet", "OPLeverage", "PctAcc", "PctTotAcc", "Price", "RDIPO", 
#       "ReturnSkew", "Size", "STreversal", "zerotradeAlt1"]]#Form the input
# y_pred = trained_models[1].predict(X_test)#Get prediction
# #Get the top 20
# y_pred_df = pd.DataFrame(y_pred)
# y_pred_df.columns = ['y_pred']
# Test_data = pd.merge(Test_data, y_pred_df, left_index=True, right_index=True)

# %%
# Test_data

# %%
# top_20 = pd.DataFrame(Test_data.sort_values(by='y_pred', ascending=False).head(20))
# top_20

# %%
#TEST ONLY

# Test_data = Test_df[Test_df['yyyymm'] == 200701]
# X_test = Test_data[['Investor_sentiment_3MA', 'News_sentiment_3MA',
#           "Consumer_sentiment_3MA", "betaVIX", "BookLeverage", "ConvDebt", "DolVol", "hire",
#           "IdioVol3F", "IndMom", "MaxRet", "OPLeverage", "PctAcc", "PctTotAcc", "Price", "RDIPO", 
#           "ReturnSkew", "Size", "STreversal", "zerotradeAlt1"]]#Form the input
# y_pred = trained_models[1].predict(X_test)#Get prediction
# #Get the top 20
# y_pred_df = pd.DataFrame(y_pred)
# # Rank the values in descending order and select the top 20

# %%
# top_20 = pd.DataFrame(y_pred_df.iloc[:, 0].sort_values(ascending=False).head(20))
# top_20.columns = ['y_pred']
# top_20['weight']=0.05
# top_20['return'] = top_20['weight'] * top_20['y_pred']

# %%
# top_20_return = top_20['return'].sum()

# %%
#Load saved models:
model_loaded = load_model('saved_models/model_2.h5')

# %%
test_data = testing_splits[1]

X_test = test_data[['News_sentiment_3MA', 'Consumer_sentiment_3MA', 'Investor_sentiment_3MA','betaVIX', 
           'BookLeverage', 'ConvDebt', 'DolVol', 'hire', 'IdioVol3F', 'IndMom', 'MaxRet',
           'OPLeverage', 'PctAcc', 'RDIPO', 'ReturnSkew', 'Size', 'STreversal','zerotradeAlt1']]##Extract testing test
y_test = test_data[["forward_return_div100"]]##Extract testing set

# %%
len(y_pred)
# Out:
# 4887

# %%
#Using testing sample from 2007 to 2012 to see whether it works well
portfolio_returns = []
Test_df = testing_splits[1].reset_index()

for Date in Date_holder:#Date rolling forwards(5 years equals 60 months, which means the cycle is 60)
    Test_data = Test_df[Test_df['yyyymm'] == Date]#Filter the data by date
    Test_data.reset_index(inplace = True, drop = True)
    X_test = Test_data[['News_sentiment_3MA', 'Consumer_sentiment_3MA', 'Investor_sentiment_3MA','betaVIX', 
           'BookLeverage', 'ConvDebt', 'DolVol', 'hire', 'IdioVol3F', 'IndMom', 'MaxRet',
           'OPLeverage', 'PctAcc', 'RDIPO', 'ReturnSkew', 'Size', 'STreversal','zerotradeAlt1']]#Form the input
    y_pred = trained_models[1].predict(X_test)#Get prediction
    #Get the top 20
    y_pred_df = pd.DataFrame(y_pred)
    # Rank the values in descending order and select the top 20
    y_pred_df.columns = ['y_pred']
    Test_data = pd.merge(Test_data, y_pred_df, left_index=True, right_index=True)
    top_20 = pd.DataFrame(Test_data.sort_values(by='y_pred', ascending=False).head(20))
    top_20['weight']=0.05
    top_20['return'] = top_20['weight'] * top_20['forward_return_div100']
    top_20_return = top_20['return'].sum()
    # Append the portfolio return to the list
    portfolio_returns.append(top_20_return)
    cumulative_return = np.cumprod(np.array(portfolio_returns) + 1)

# Display the list of portfolio returns
print(cumulative_return)
# Out:
# 3/3 [==============================] - 0s 927us/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 730us/step
# 3/3 [==============================] - 0s 769us/step
# 3/3 [==============================] - 0s 695us/step
# 3/3 [==============================] - 0s 676us/step
# 3/3 [==============================] - 0s 787us/step
# 3/3 [==============================] - 0s 768us/step
# 3/3 [==============================] - 0s 824us/step
# 3/3 [==============================] - 0s 792us/step
# 3/3 [==============================] - 0s 713us/step
# 3/3 [==============================] - 0s 625us/step
# 3/3 [==============================] - 0s 727us/step
# 3/3 [==============================] - 0s 706us/step
# 3/3 [==============================] - 0s 660us/step
# 3/3 [==============================] - 0s 799us/step
# 3/3 [==============================] - 0s 696us/step
# 3/3 [==============================] - 0s 732us/step
# 3/3 [==============================] - 0s 700us/step
# 3/3 [==============================] - 0s 651us/step
# 3/3 [==============================] - 0s 695us/step
# 3/3 [==============================] - 0s 770us/step
# 3/3 [==============================] - 0s 848us/step
# 3/3 [==============================] - 0s 709us/step
# 3/3 [==============================] - 0s 672us/step
# 3/3 [==============================] - 0s 759us/step
# 3/3 [==============================] - 0s 803us/step
# 3/3 [==============================] - 0s 653us/step
# 3/3 [==============================] - 0s 696us/step
# 3/3 [==============================] - 0s 682us/step
# 3/3 [==============================] - 0s 661us/step
# 3/3 [==============================] - 0s 715us/step
# 3/3 [==============================] - 0s 677us/step
# 3/3 [==============================] - 0s 632us/step
# 3/3 [==============================] - 0s 704us/step
# 3/3 [==============================] - 0s 718us/step
# 3/3 [==============================] - 0s 645us/step
# 3/3 [==============================] - 0s 623us/step
# 3/3 [==============================] - 0s 695us/step
# 3/3 [==============================] - 0s 714us/step
# 3/3 [==============================] - 0s 670us/step
# 3/3 [==============================] - 0s 689us/step
# 3/3 [==============================] - 0s 698us/step
# 3/3 [==============================] - 0s 603us/step
# 3/3 [==============================] - 0s 653us/step
# 3/3 [==============================] - 0s 656us/step
# 3/3 [==============================] - 0s 646us/step
# 3/3 [==============================] - 0s 726us/step
# 3/3 [==============================] - 0s 664us/step
# 3/3 [==============================] - 0s 748us/step
# 3/3 [==============================] - 0s 736us/step
# 3/3 [==============================] - 0s 840us/step
# 3/3 [==============================] - 0s 721us/step
# 3/3 [==============================] - 0s 674us/step
# 3/3 [==============================] - 0s 681us/step
# 3/3 [==============================] - 0s 656us/step
# 3/3 [==============================] - 0s 725us/step
# 3/3 [==============================] - 0s 741us/step
# 3/3 [==============================] - 0s 723us/step
# 3/3 [==============================] - 0s 770us/step
# [1.00158164 0.99681396 1.03094714 1.0727448  1.06536473 1.02565916
#  1.04367757 1.10120791 1.12534986 1.07927795 1.07195546 1.04277613
#  1.00262069 0.99188292 1.05335822 1.10156965 0.99359243 0.97810389
#  1.00636178 0.88931717 0.71012233 0.67650131 0.70977656 0.65040567
#  0.63237781 0.71083516 0.80427834 0.85467817 0.87353092 0.95532458
#  0.99578144 1.04023096 1.04491068 1.12994944 1.17286966 1.15792646
#  1.20675628 1.26425088 1.32584415 1.23145773 1.18668825 1.27663483
#  1.22789524 1.33782414 1.39215737 1.36186855 1.43776536 1.49966829
#  1.53123469 1.536866   1.58882366 1.57896925 1.56183303 1.47432431
#  1.48166133 1.42704569 1.58426621 1.57368345 1.61105864 1.60436564]

# %%
top_20_return
# Out:
# -0.004154415170000001

# %%
#Clean the dataframe for plotting
cum_return_df = pd.DataFrame({"cum_return": cumulative_return, "Date": Date_holder})
# cum_return_df.columns = ['cum_return', "Date"]
cum_return_df["Date"] = pd.to_datetime(cum_return_df["Date"], format='%Y%m', errors='coerce')

# %%
sp500_2007_2012 = pd.read_csv("sp500_2007_2012.csv")

# %%
sp500_2007_2012["Date"] = pd.to_datetime(sp500_2007_2012["Date"], format='%Y%m', errors='coerce')

# %%
#Plotting
plt.figure(figsize=(10, 6))
plt.plot(cum_return_df["Date"], cum_return_df['cum_return'], "-b", label="model_top20")
plt.plot(sp500_2007_2012["Date"], sp500_2007_2012["SP500_return"], "-r", label = "sp500")
plt.title("Predicted Returns")
plt.xlabel("Time")
plt.ylabel("Predicted Returns")
plt.legend()
plt.grid(True)

# %%
# plt.figure(figsize=(10, 6))
# plt.scatter(y_test, y_pred, alpha=0.5)
# plt.title("Actual vs. Predicted Values")
# plt.xlabel("Actual Values")
# plt.ylabel("Predicted Values")
# plt.grid(True)

# # Add a 45-degree reference line for comparison
# plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
# plt.show()

# %%
Test_df = main_df[main_df['yyyymm'] > 200201].reset_index()

# %%
#Using data from starting from 2002
Test_df = main_df[main_df['yyyymm'] >= 200201].reset_index()
Date_holder = Test_df["yyyymm"].unique()
portfolio_returns_top20 = []
portfolio_returns_top10 = []
portfolio_returns_top5 = []
portfolio_returns_randamu = []

for Date in Date_holder:#Date rolling forwards(5 years equals 60 months, which means the cycle is 60)
    Test_data = Test_df[Test_df['yyyymm'] == Date]#Filter the data by date
    Test_data.reset_index(inplace = True, drop = True)
    X_test = Test_data[['News_sentiment_3MA', 'Consumer_sentiment_3MA', 'Investor_sentiment_3MA','betaVIX', 
           'BookLeverage', 'ConvDebt', 'DolVol', 'hire', 'IdioVol3F', 'IndMom', 'MaxRet',
           'OPLeverage', 'PctAcc', 'RDIPO', 'ReturnSkew', 'Size', 'STreversal','zerotradeAlt1']]#Form the input
    y_pred = trained_models[1].predict(X_test)#Get prediction
    #Get the top 20
    y_pred_df = pd.DataFrame(y_pred)
    # Rank the values in descending order and select the top 20
    y_pred_df.columns = ['y_pred']
    Test_data = pd.merge(Test_data, y_pred_df, left_index=True, right_index=True)
    top_20 = pd.DataFrame(Test_data.sort_values(by='y_pred', ascending=False).head(20))
    top_20['weight']=0.05
    top_20['return'] = top_20['weight'] * top_20['forward_return_div100']
    top_20_return = top_20['return'].sum()
    top_10 = pd.DataFrame(Test_data.sort_values(by='y_pred', ascending=False).head(10))
    top_10['weight']=0.1
    top_10['return'] = top_10['weight'] * top_10['forward_return_div100']
    top_10_return = top_10['return'].sum()
    top_5 = pd.DataFrame(Test_data.sort_values(by='y_pred', ascending=False).head(5))
    top_5['weight']=0.2
    top_5['return'] = top_5['weight'] * top_5['forward_return_div100']
    top_5_return = top_5['return'].sum()
    Randamu = pd.DataFrame(Test_data.sample(n=20, random_state=42))
    Randamu['weight']=0.05
    Randamu['return'] = Randamu['weight'] * Randamu['forward_return_div100']
    Randamu_return = Randamu['return'].sum()
    
    # Append the portfolio return to the list
    portfolio_returns_top20.append(top_20_return)
    portfolio_returns_top10.append(top_10_return)
    portfolio_returns_top5.append(top_5_return)
    portfolio_returns_randamu.append(Randamu_return)
    
cumulative_return_top20 = np.cumprod(np.array(portfolio_returns_top20) + 1) - 1
cumulative_return_top10 = np.cumprod(np.array(portfolio_returns_top10) + 1) - 1
cumulative_return_top5 = np.cumprod(np.array(portfolio_returns_top5) + 1) - 1
cumulative_return_randamu = np.cumprod(np.array(portfolio_returns_randamu) + 1) - 1
# Out:
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 585us/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 540us/step
# 3/3 [==============================] - 0s 511us/step
# 3/3 [==============================] - 0s 735us/step
# 3/3 [==============================] - 0s 637us/step
# 3/3 [==============================] - 0s 549us/step
# 3/3 [==============================] - 0s 618us/step
# 3/3 [==============================] - 0s 552us/step
# 3/3 [==============================] - 0s 620us/step
# 3/3 [==============================] - 0s 707us/step
# 3/3 [==============================] - 0s 656us/step
# 3/3 [==============================] - 0s 584us/step
# 3/3 [==============================] - 0s 630us/step
# 3/3 [==============================] - 0s 563us/step
# 3/3 [==============================] - 0s 843us/step
# 3/3 [==============================] - 0s 597us/step
# 3/3 [==============================] - 0s 692us/step
# 3/3 [==============================] - 0s 664us/step
# 3/3 [==============================] - 0s 699us/step
# 3/3 [==============================] - 0s 597us/step
# 3/3 [==============================] - 0s 775us/step
# 3/3 [==============================] - 0s 644us/step
# 3/3 [==============================] - 0s 653us/step
# 3/3 [==============================] - 0s 585us/step
# 3/3 [==============================] - 0s 693us/step
# 3/3 [==============================] - 0s 634us/step
# 3/3 [==============================] - 0s 699us/step
# 3/3 [==============================] - 0s 664us/step
# 3/3 [==============================] - 0s 885us/step
# 3/3 [==============================] - 0s 832us/step
# 3/3 [==============================] - 0s 915us/step
# 3/3 [==============================] - 0s 643us/step
# 3/3 [==============================] - 0s 983us/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 784us/step
# 3/3 [==============================] - 0s 751us/step
# 3/3 [==============================] - 0s 688us/step
# 3/3 [==============================] - 0s 689us/step
# 3/3 [==============================] - 0s 685us/step
# 3/3 [==============================] - 0s 639us/step
# 3/3 [==============================] - 0s 690us/step
# 3/3 [==============================] - 0s 681us/step
# 3/3 [==============================] - 0s 612us/step
# 3/3 [==============================] - 0s 529us/step
# 3/3 [==============================] - 0s 656us/step
# 3/3 [==============================] - 0s 587us/step
# 3/3 [==============================] - 0s 571us/step
# 3/3 [==============================] - 0s 712us/step
# 3/3 [==============================] - 0s 623us/step
# 3/3 [==============================] - 0s 580us/step
# 3/3 [==============================] - 0s 687us/step
# 3/3 [==============================] - 0s 664us/step
# 3/3 [==============================] - 0s 804us/step
# 3/3 [==============================] - 0s 641us/step
# 3/3 [==============================] - 0s 597us/step
# 3/3 [==============================] - 0s 563us/step
# 3/3 [==============================] - 0s 740us/step
# 3/3 [==============================] - 0s 620us/step
# 3/3 [==============================] - 0s 568us/step
# 3/3 [==============================] - 0s 613us/step
# 3/3 [==============================] - 0s 733us/step
# 3/3 [==============================] - 0s 795us/step
# 3/3 [==============================] - 0s 625us/step
# 3/3 [==============================] - 0s 648us/step
# 3/3 [==============================] - 0s 708us/step
# 3/3 [==============================] - 0s 667us/step
# 3/3 [==============================] - 0s 546us/step
# 3/3 [==============================] - 0s 670us/step
# 3/3 [==============================] - 0s 662us/step
# 3/3 [==============================] - 0s 581us/step
# 3/3 [==============================] - 0s 599us/step
# 3/3 [==============================] - 0s 612us/step
# 3/3 [==============================] - 0s 621us/step
# 3/3 [==============================] - 0s 754us/step
# 3/3 [==============================] - 0s 594us/step
# 3/3 [==============================] - 0s 669us/step
# 3/3 [==============================] - 0s 639us/step
# 3/3 [==============================] - 0s 632us/step
# 3/3 [==============================] - 0s 664us/step
# 3/3 [==============================] - 0s 622us/step
# 3/3 [==============================] - 0s 859us/step
# 3/3 [==============================] - 0s 693us/step
# 3/3 [==============================] - 0s 572us/step
# 3/3 [==============================] - 0s 670us/step
# 3/3 [==============================] - 0s 602us/step
# 3/3 [==============================] - 0s 587us/step
# 3/3 [==============================] - 0s 606us/step
# 3/3 [==============================] - 0s 622us/step
# 3/3 [==============================] - 0s 838us/step
# 3/3 [==============================] - 0s 637us/step
# 3/3 [==============================] - 0s 660us/step
# 3/3 [==============================] - 0s 612us/step
# 3/3 [==============================] - 0s 716us/step
# 3/3 [==============================] - 0s 603us/step
# 3/3 [==============================] - 0s 617us/step
# 3/3 [==============================] - 0s 624us/step
# 3/3 [==============================] - 0s 559us/step
# 3/3 [==============================] - 0s 650us/step
# 3/3 [==============================] - 0s 597us/step
# 3/3 [==============================] - 0s 710us/step
# 3/3 [==============================] - 0s 679us/step
# 3/3 [==============================] - 0s 619us/step
# 3/3 [==============================] - 0s 603us/step
# 3/3 [==============================] - 0s 594us/step
# 3/3 [==============================] - 0s 690us/step
# 3/3 [==============================] - 0s 582us/step
# 3/3 [==============================] - 0s 611us/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 720us/step
# 3/3 [==============================] - 0s 625us/step
# 3/3 [==============================] - 0s 740us/step
# 3/3 [==============================] - 0s 558us/step
# 3/3 [==============================] - 0s 625us/step
# 3/3 [==============================] - 0s 628us/step
# 3/3 [==============================] - 0s 708us/step
# 3/3 [==============================] - 0s 648us/step
# 3/3 [==============================] - 0s 571us/step
# 3/3 [==============================] - 0s 596us/step
# 3/3 [==============================] - 0s 637us/step
# 3/3 [==============================] - 0s 655us/step
# 3/3 [==============================] - 0s 556us/step
# 3/3 [==============================] - 0s 618us/step
# 3/3 [==============================] - 0s 584us/step
# 3/3 [==============================] - 0s 645us/step
# 3/3 [==============================] - 0s 680us/step
# 3/3 [==============================] - 0s 672us/step
# 3/3 [==============================] - 0s 583us/step
# 3/3 [==============================] - 0s 690us/step
# 3/3 [==============================] - 0s 662us/step
# 3/3 [==============================] - 0s 746us/step
# 3/3 [==============================] - 0s 543us/step
# 3/3 [==============================] - 0s 596us/step
# 3/3 [==============================] - 0s 677us/step
# 3/3 [==============================] - 0s 686us/step
# 3/3 [==============================] - 0s 571us/step
# 3/3 [==============================] - 0s 638us/step
# 3/3 [==============================] - 0s 532us/step
# 3/3 [==============================] - 0s 619us/step
# 3/3 [==============================] - 0s 631us/step
# 3/3 [==============================] - 0s 612us/step
# 3/3 [==============================] - 0s 654us/step
# 3/3 [==============================] - 0s 546us/step
# 3/3 [==============================] - 0s 646us/step
# 3/3 [==============================] - 0s 660us/step
# 3/3 [==============================] - 0s 754us/step
# 3/3 [==============================] - 0s 608us/step
# 3/3 [==============================] - 0s 545us/step
# 3/3 [==============================] - 0s 638us/step
# 3/3 [==============================] - 0s 590us/step
# 3/3 [==============================] - 0s 641us/step
# 3/3 [==============================] - 0s 638us/step
# 3/3 [==============================] - 0s 609us/step
# 3/3 [==============================] - 0s 674us/step
# 3/3 [==============================] - 0s 692us/step
# 3/3 [==============================] - 0s 665us/step
# 3/3 [==============================] - 0s 555us/step
# 3/3 [==============================] - 0s 677us/step
# 3/3 [==============================] - 0s 625us/step
# 3/3 [==============================] - 0s 617us/step
# 3/3 [==============================] - 0s 705us/step
# 3/3 [==============================] - 0s 711us/step
# 3/3 [==============================] - 0s 602us/step
# 3/3 [==============================] - 0s 675us/step
# 3/3 [==============================] - 0s 711us/step
# 3/3 [==============================] - 0s 566us/step
# 3/3 [==============================] - 0s 643us/step
# 3/3 [==============================] - 0s 709us/step
# 3/3 [==============================] - 0s 673us/step
# 3/3 [==============================] - 0s 504us/step
# 3/3 [==============================] - 0s 618us/step
# 3/3 [==============================] - 0s 638us/step
# 3/3 [==============================] - 0s 708us/step
# 3/3 [==============================] - 0s 528us/step
# 3/3 [==============================] - 0s 682us/step
# 3/3 [==============================] - 0s 739us/step
# 3/3 [==============================] - 0s 609us/step
# 3/3 [==============================] - 0s 603us/step
# 3/3 [==============================] - 0s 595us/step
# 3/3 [==============================] - 0s 705us/step
# 3/3 [==============================] - 0s 607us/step
# 3/3 [==============================] - 0s 622us/step
# 3/3 [==============================] - 0s 623us/step
# 3/3 [==============================] - 0s 790us/step
# 3/3 [==============================] - 0s 715us/step
# 3/3 [==============================] - 0s 577us/step
# 3/3 [==============================] - 0s 568us/step
# 3/3 [==============================] - 0s 677us/step
# 3/3 [==============================] - 0s 569us/step
# 3/3 [==============================] - 0s 579us/step
# 3/3 [==============================] - 0s 500us/step
# 3/3 [==============================] - 0s 687us/step
# 3/3 [==============================] - 0s 765us/step
# 3/3 [==============================] - 0s 633us/step
# 3/3 [==============================] - 0s 602us/step
# 3/3 [==============================] - 0s 588us/step
# 3/3 [==============================] - 0s 699us/step
# 3/3 [==============================] - 0s 702us/step
# 3/3 [==============================] - 0s 573us/step
# 3/3 [==============================] - 0s 596us/step
# 3/3 [==============================] - 0s 589us/step
# 3/3 [==============================] - 0s 698us/step
# 3/3 [==============================] - 0s 603us/step
# 3/3 [==============================] - 0s 600us/step
# 3/3 [==============================] - 0s 600us/step
# 3/3 [==============================] - 0s 794us/step
# 3/3 [==============================] - 0s 566us/step
# 3/3 [==============================] - 0s 659us/step
# 3/3 [==============================] - 0s 606us/step
# 3/3 [==============================] - 0s 816us/step
# 3/3 [==============================] - 0s 631us/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 625us/step
# 3/3 [==============================] - 0s 653us/step
# 3/3 [==============================] - 0s 605us/step
# 3/3 [==============================] - 0s 713us/step
# 3/3 [==============================] - 0s 607us/step
# 3/3 [==============================] - 0s 815us/step
# 3/3 [==============================] - 0s 678us/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 640us/step
# 3/3 [==============================] - 0s 628us/step
# 3/3 [==============================] - 0s 559us/step
# 3/3 [==============================] - 0s 673us/step
# 3/3 [==============================] - 0s 600us/step
# 3/3 [==============================] - 0s 579us/step
# 3/3 [==============================] - 0s 555us/step
# 3/3 [==============================] - 0s 561us/step
# 3/3 [==============================] - 0s 505us/step
# 3/3 [==============================] - 0s 623us/step
# 3/3 [==============================] - 0s 687us/step
# 3/3 [==============================] - 0s 551us/step
# 3/3 [==============================] - 0s 531us/step
# 3/3 [==============================] - 0s 540us/step
# 3/3 [==============================] - 0s 759us/step
# 3/3 [==============================] - 0s 693us/step

# %%
#Transform the cumulative return dataset
cum_return_df_top20 = pd.DataFrame({"cum_return_top20": cumulative_return_top20, "Date": Date_holder})
# cum_return_df.columns = ['cum_return', "Date"]
cum_return_df_top20["Date"] = pd.to_datetime(cum_return_df_top20["Date"], format='%Y%m', errors='coerce')
cum_return_df_top10 = pd.DataFrame({"cum_return_top10": cumulative_return_top10, "Date": Date_holder})
cum_return_df_top10["Date"] = pd.to_datetime(cum_return_df_top10["Date"], format='%Y%m', errors='coerce')
cum_return_df_top5 = pd.DataFrame({"cum_return_top5": cumulative_return_top5, "Date": Date_holder})
cum_return_df_top5["Date"] = pd.to_datetime(cum_return_df_top5["Date"], format='%Y%m', errors='coerce')
cum_return_df_randamu = pd.DataFrame({"cum_return_randamu": cumulative_return_randamu, "Date": Date_holder})
cum_return_df_randamu["Date"] = pd.to_datetime(cum_return_df_randamu["Date"], format='%Y%m', errors='coerce')

# %%
#Transform the cumulative return dataset
portfolio_returns_top20_df = pd.DataFrame({"return_top20": portfolio_returns_top20, "Date": Date_holder})
# cum_return_df.columns = ['cum_return', "Date"]
portfolio_returns_top20_df["Date"] = pd.to_datetime(portfolio_returns_top20_df["Date"], format='%Y%m', errors='coerce')
portfolio_returns_top10_df = pd.DataFrame({"return_top10": portfolio_returns_top10, "Date": Date_holder})
portfolio_returns_top10_df["Date"] = pd.to_datetime(portfolio_returns_top10_df["Date"], format='%Y%m', errors='coerce')
portfolio_returns_top5_df = pd.DataFrame({"return_top5": portfolio_returns_top5, "Date": Date_holder})
portfolio_returns_top5_df["Date"] = pd.to_datetime(portfolio_returns_top5_df["Date"], format='%Y%m', errors='coerce')
portfolio_returns_randamu_df = pd.DataFrame({"return_randamu": portfolio_returns_randamu, "Date": Date_holder})
portfolio_returns_randamu_df["Date"] = pd.to_datetime(portfolio_returns_randamu_df["Date"], format='%Y%m', errors='coerce')

# %%
cum_return_df_randamu["Date"].max()
# Out:
# Timestamp('2021-09-01 00:00:00')

# %%
sp500_return = pd.read_csv("S&P_Cumulative_Return.csv")

# %%
sp500_return
# Out:
#        Date  SP500_Return
# 0    200202      0.986402
# 1    200203      1.021992
# 2    200204      0.957213
# 3    200205      0.948480
# 4    200206      0.877141
# ..      ...           ...
# 231  202105      3.006675
# 232  202106      3.072735
# 233  202107      3.141850
# 234  202108      3.231638
# 235  202109      3.074135
#
# [236 rows x 2 columns]

# %%
sp500_return["Date"] = pd.to_datetime(sp500_return["Date"], format='%Y%m', errors='coerce')

# %%
sp_ff = pd.read_csv("S&P F-F_Research_Data_Factors_2002_2022.csv")
sp_ff["Date"] = pd.to_datetime(sp_ff["Date"], format='%Y%m', errors='coerce')

# %%
#Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(cum_return_df_top20["Date"], cum_return_df_top20['cum_return_top20'], label="top20")
plt.plot(cum_return_df_top10["Date"], cum_return_df_top10['cum_return_top10'], label="top10")
plt.plot(cum_return_df_top5["Date"], cum_return_df_top5['cum_return_top5'], label="top5")
plt.plot(cum_return_df_randamu["Date"], cum_return_df_randamu['cum_return_randamu'], label="random 20")
plt.plot(sp500_return["Date"], sp500_return["SP500_Return_MinusOne"], label="SP500")
plt.title("Predicted Returns")
plt.xlabel("Time")
plt.ylabel("Predicted Returns")
plt.legend()
plt.grid(True)

# %% [markdown]
# ### Test the model against fama french

# %%
#Data all mesh together
all_in_one = pd.merge(portfolio_returns_top20_df, 
                      pd.merge(portfolio_returns_top10_df, 
                               pd.merge(portfolio_returns_top5_df, 
                                        pd.merge(portfolio_returns_randamu_df, 
                                                 pd.merge(sp_ff, sp500_return, on = "Date"), on = "Date"), on = "Date"), on = "Date"), on = "Date")

# %%
all_in_one = pd.merge(all_in_one, 
                       pd.merge(cum_return_df_top20,
                                pd.merge(cum_return_df_top10, 
                                         pd.merge(cum_return_df_top5, cum_return_df_randamu))))

# %%
all_in_one
# Out:
#      return_top20       Date  return_top10  return_top5  return_randamu  \
# 0        0.067724 2002-02-01      0.078373     0.134365        0.051646
# 1       -0.018798 2002-03-01     -0.015902    -0.008178       -0.038263
# 2       -0.022914 2002-04-01     -0.059388    -0.052573       -0.033135
# 3       -0.109013 2002-05-01     -0.129247    -0.084096       -0.111052
# 4       -0.089830 2002-06-01     -0.139064    -0.121365       -0.131493
# ..            ...        ...           ...          ...             ...
# 231     -0.000558 2021-05-01      0.007270     0.030607       -0.024812
# 232      0.009043 2021-06-01     -0.012560    -0.005643        0.020176
# 233      0.020307 2021-07-01      0.005328    -0.010992        0.009700
# 234     -0.039291 2021-08-01     -0.027641     0.031404       -0.044130
# 235      0.065452 2021-09-01      0.073693     0.079003        0.063078
#
#      Mkt-RF  Mkt-Rf_div100   SMB   HML    RF  ...  SMB-Rf  HML-RF  Mkt-Rf_Cum  \
# 0     -2.29        -0.0229 -1.01  2.16  0.13  ... -0.0114  0.0203    0.963030
# 1      4.24         0.0424  4.21  1.06  0.13  ...  0.0408  0.0093    1.003862
# 2     -5.20        -0.0520  5.96  3.88  0.15  ...  0.0581  0.0373    0.951661
# 3     -1.38        -0.0138 -3.21  1.53  0.14  ... -0.0335  0.0139    0.938528
# 4     -7.21        -0.0721  4.29 -0.05  0.13  ...  0.0416 -0.0018    0.870861
# ..      ...            ...   ...   ...   ...  ...     ...     ...         ...
# 231    0.29         0.0029 -0.25  7.09  0.00  ... -0.0025  0.0709    4.771061
# 232    2.75         0.0275  1.68 -7.87  0.00  ...  0.0168 -0.0787    4.902265
# 233    1.27         0.0127 -3.97 -1.78  0.00  ... -0.0397 -0.0178    4.964524
# 234    2.91         0.0291 -0.42 -0.15  0.00  ... -0.0042 -0.0015    5.108991
# 235   -4.37        -0.0437  0.71  5.08  0.00  ...  0.0071  0.0508    4.885728
#
#      SMB-Rf_Cum  HML-RF_Cum  SP500_Return  cum_return_top20  cum_return_top10  \
# 0      0.998980    1.053970      0.986402          1.053477          1.052308
# 1      1.039739    1.063772      1.021992          1.033674          1.035575
# 2      1.100148    1.103451      0.957213          1.009988          0.974074
# 3      1.063293    1.118788      0.948480          0.899887          0.848178
# 4      1.107526    1.116775      0.877141          0.819050          0.730227
# ..          ...         ...           ...               ...               ...
# 231    1.212823    0.631786      3.006675         17.103172         10.908442
# 232    1.233199    0.582064      3.072735         17.257829         10.771431
# 233    1.184241    0.571703      3.141850         17.608275         10.828823
# 234    1.179267    0.570846      3.231638         16.916429         10.529504
# 235    1.187640    0.599845      3.074135         18.023640         11.305453
#
#      cum_return_top5  cum_return_randamu
# 0           1.076740            1.054291
# 1           1.067935            1.013951
# 2           1.011790            0.980354
# 3           0.926703            0.871484
# 4           0.814234            0.756889
# ..               ...                 ...
# 231        13.599796           11.950366
# 232        13.523057           12.191476
# 233        13.374407           12.309734
# 234        13.794422           11.766507
# 235        14.884224           12.508719
#
# [236 rows x 21 columns]

# %%
all_in_one["RF_div100"] = all_in_one["RF"]/100

# %%
all_in_one
# Out:
#      return_top20       Date  return_top10  return_top5  return_randamu  \
# 0        0.067724 2002-02-01      0.078373     0.134365        0.051646
# 1       -0.018798 2002-03-01     -0.015902    -0.008178       -0.038263
# 2       -0.022914 2002-04-01     -0.059388    -0.052573       -0.033135
# 3       -0.109013 2002-05-01     -0.129247    -0.084096       -0.111052
# 4       -0.089830 2002-06-01     -0.139064    -0.121365       -0.131493
# ..            ...        ...           ...          ...             ...
# 231     -0.000558 2021-05-01      0.007270     0.030607       -0.024812
# 232      0.009043 2021-06-01     -0.012560    -0.005643        0.020176
# 233      0.020307 2021-07-01      0.005328    -0.010992        0.009700
# 234     -0.039291 2021-08-01     -0.027641     0.031404       -0.044130
# 235      0.065452 2021-09-01      0.073693     0.079003        0.063078
#
#      Mkt-RF  Mkt-Rf_div100   SMB   HML    RF  ...  HML-RF  Mkt-Rf_Cum  \
# 0     -2.29        -0.0229 -1.01  2.16  0.13  ...  0.0203    0.963030
# 1      4.24         0.0424  4.21  1.06  0.13  ...  0.0093    1.003862
# 2     -5.20        -0.0520  5.96  3.88  0.15  ...  0.0373    0.951661
# 3     -1.38        -0.0138 -3.21  1.53  0.14  ...  0.0139    0.938528
# 4     -7.21        -0.0721  4.29 -0.05  0.13  ... -0.0018    0.870861
# ..      ...            ...   ...   ...   ...  ...     ...         ...
# 231    0.29         0.0029 -0.25  7.09  0.00  ...  0.0709    4.771061
# 232    2.75         0.0275  1.68 -7.87  0.00  ... -0.0787    4.902265
# 233    1.27         0.0127 -3.97 -1.78  0.00  ... -0.0178    4.964524
# 234    2.91         0.0291 -0.42 -0.15  0.00  ... -0.0015    5.108991
# 235   -4.37        -0.0437  0.71  5.08  0.00  ...  0.0508    4.885728
#
#      SMB-Rf_Cum  HML-RF_Cum  SP500_Return  top20-RF  top10-RF   top5-RF  \
# 0      0.998980    1.053970      0.986402 -0.062276 -0.051627  0.004365
# 1      1.039739    1.063772      1.021992 -0.148798 -0.145902 -0.138178
# 2      1.100148    1.103451      0.957213 -0.172914 -0.209388 -0.202573
# 3      1.063293    1.118788      0.948480 -0.249013 -0.269247 -0.224096
# 4      1.107526    1.116775      0.877141 -0.219830 -0.269064 -0.251365
# ..          ...         ...           ...       ...       ...       ...
# 231    1.212823    0.631786      3.006675 -0.000558  0.007270  0.030607
# 232    1.233199    0.582064      3.072735  0.009043 -0.012560 -0.005643
# 233    1.184241    0.571703      3.141850  0.020307  0.005328 -0.010992
# 234    1.179267    0.570846      3.231638 -0.039291 -0.027641  0.031404
# 235    1.187640    0.599845      3.074135  0.065452  0.073693  0.079003
#
#      randamu-RF  RF_div100
# 0     -0.078354     0.0013
# 1     -0.168263     0.0013
# 2     -0.183135     0.0015
# 3     -0.251052     0.0014
# 4     -0.261493     0.0013
# ..          ...        ...
# 231   -0.024812     0.0000
# 232    0.020176     0.0000
# 233    0.009700     0.0000
# 234   -0.044130     0.0000
# 235    0.063078     0.0000
#
# [236 rows x 22 columns]

# %%
all_in_one["top20-RF"] = all_in_one["return_top20"] - all_in_one["RF_div100"]
all_in_one["top10-RF"] = all_in_one["return_top10"] - all_in_one["RF_div100"]
all_in_one["top5-RF"] = all_in_one["return_top5"] - all_in_one["RF_div100"]
all_in_one["randamu-RF"] = all_in_one["return_randamu"] - all_in_one["RF_div100"]

# %%
import statsmodels.api as sm

# %%
plt.figure(figsize=(10, 6))
plt.plot(all_in_one["Date"], all_in_one['Mkt-Rf_div100'], label="market")
plt.plot(all_in_one["Date"], all_in_one['top20-RF'], label="top20")
plt.title("Predicted Returns")
plt.xlabel("Time")
plt.ylabel("Predicted Returns")
plt.legend()
plt.grid(True)

# %%
x = all_in_one[['Mkt-Rf_div100', "HML-RF", "SMB-Rf"]]
y = all_in_one[['top20-RF']]
x = sm.add_constant(x)
result = sm.OLS(y, x).fit()
 
# printing the summary table
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               top20-RF   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.407
# Date:                Fri, 03 Nov 2023   Prob (F-statistic):              0.242
# Time:                        00:09:46   Log-Likelihood:                 387.37
# No. Observations:                 236   AIC:                            -766.7
# Df Residuals:                     232   BIC:                            -752.9
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0117      0.003      3.726      0.000       0.006       0.018
# Mkt-Rf_div100     0.0837      0.076      1.104      0.271      -0.066       0.233
# HML-RF           -0.1654      0.112     -1.477      0.141      -0.386       0.055
# SMB-Rf           -0.1533      0.132     -1.160      0.247      -0.414       0.107
# ==============================================================================
# Omnibus:                       24.618   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.965
# Skew:                          -0.370   Prob(JB):                     8.68e-17
# Kurtosis:                       5.641   Cond. No.                         44.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Maximum drawdown

# %%
cumulative_returns_top20 = all_in_one['cum_return_top20']
peak_value = cumulative_returns_top20[0]
max_drawdown = 0.0

for value in cumulative_returns_top20:
    if value > peak_value:
        peak_value = value
    else:
        drawdown = (peak_value - value) / peak_value
        max_drawdown = max(max_drawdown, drawdown)

# Convert the maximum drawdown to a percentage
max_drawdown_percentage = max_drawdown * 100

print(f"Maximum Drawdown: {max_drawdown_percentage:.2f}%")
# Out:
# Maximum Drawdown: 43.81%

# %%
cumulative_returns_top10 = all_in_one['cum_return_top10']
peak_value = cumulative_returns_top10[0]
max_drawdown = 0.0

for value in cumulative_returns_top10:
    if value > peak_value:
        peak_value = value
    else:
        drawdown = (peak_value - value) / peak_value
        max_drawdown = max(max_drawdown, drawdown)

# Convert the maximum drawdown to a percentage
max_drawdown_percentage = max_drawdown * 100

print(f"Maximum Drawdown: {max_drawdown_percentage:.2f}%")
# Out:
# Maximum Drawdown: 45.65%

# %%
cumulative_returns_top5 = all_in_one['cum_return_top5']
peak_value = cumulative_returns_top5[0]
max_drawdown = 0.0

for value in cumulative_returns_top5:
    if value > peak_value:
        peak_value = value
    else:
        drawdown = (peak_value - value) / peak_value
        max_drawdown = max(max_drawdown, drawdown)

# Convert the maximum drawdown to a percentage
max_drawdown_percentage = max_drawdown * 100

print(f"Maximum Drawdown: {max_drawdown_percentage:.2f}%")
# Out:
# Maximum Drawdown: 59.59%

# %%
cumulative_returns_randamu = all_in_one['cum_return_randamu']
peak_value = cumulative_returns_randamu[0]
max_drawdown = 0.0

for value in cumulative_returns_randamu:
    if value > peak_value:
        peak_value = value
    else:
        drawdown = (peak_value - value) / peak_value
        max_drawdown = max(max_drawdown, drawdown)

# Convert the maximum drawdown to a percentage
max_drawdown_percentage = max_drawdown * 100

print(f"Maximum Drawdown: {max_drawdown_percentage:.2f}%")
# Out:
# Maximum Drawdown: 44.19%

# %%
# Sort the cumulative returns in ascending order
sorted_returns = all_in_one['cum_return_top20'].sort_values()

# Calculate the index for the 10th percentile (90% confidence level)
index = int(0.1 * len(sorted_returns))

# Retrieve the VaR(90) value
var_90 = sorted_returns.iloc[index]

print(f"VaR(90) is: {var_90:.4f}")
# Out:
# VaR(90) is: 1.0812

# %%
from scipy.stats import norm
def VaR_90(returns):
    confidence_level = 0.90
    z_score = norm.ppf(1 - (1 - confidence_level) / 2)
    VaR_90 = np.percentile(returns, z_score)
    return VaR_90

# %%
VaR_90per = VaR_90(all_in_one["return_randamu"])
VaR_90per
# Out:
# -0.10203511287276097

# %%
average_excess_return = (all_in_one['top5-RF'].mean())
std_deviation_excess = all_in_one['top5-RF'].std()

# Calculate the Sharpe Ratio
sharpe_ratio = (average_excess_return) / std_deviation_excess

# Assuming the data is daily, you can annualize the Sharpe Ratio
annualized_sharpe_ratio = sharpe_ratio * np.sqrt(12)  # Assuming 252 trading days in a year

print(f"Annualized Sharpe Ratio: {annualized_sharpe_ratio:.4f}")
# Out:
# Annualized Sharpe Ratio: 0.7253

# %% [markdown]
# ### Store the model

# %%
import os

# Define a directory where you want to save the models
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist

# Iterate through your trained models
for i, model in enumerate(trained_models):
    model_name = f"model_{i + 1}.h5"  # Define a unique name for each model
    model_path = os.path.join(save_dir, model_name)  # Full path to save the model

    # Save the model to the specified path
    model.save(model_path)

    print(f"Model {i + 1} saved to {model_path}")
# Out:
# Model 1 saved to saved_models/model_1.h5
# Model 2 saved to saved_models/model_2.h5
# Model 3 saved to saved_models/model_3.h5
# Model 4 saved to saved_models/model_4.h5

# %%
all_in_one.to_csv('all_in_one.csv')
